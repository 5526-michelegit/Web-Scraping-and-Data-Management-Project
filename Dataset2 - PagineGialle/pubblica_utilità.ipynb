# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.firefox.options import Options as options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
my_firefox_path = r'C:\Users\Alberto\Downloads\geckodriver.exe'
print("Starting operations!")

serv = Service(my_firefox_path)
driver = webdriver.Firefox(service=serv)

url_base = 'https://www.paginegialle.it/ricerca/'

qrt_list = ['Quartiere Adriano',
 'Quartiere Affori',
 'Quartiere Baggio',
 'Quartiere Bande Nere',
 'Quartiere Barona',
 'Quartiere Bicocca',
 'Quartiere Bovisa',
 'Quartiere Bovisasca',
 'Quartiere Bruzzano',
 'Quartiere Cantalupa',
 'Quartiere Centrale',
 'Quartiere Chiaravalle',
 'Quartiere Città Studi',
 'Quartiere Comasina',
 'Quartiere Corsica',
 'Quartiere Dergano',
 'Quartiere Duomo',
 'Quartiere Farini',
 'Quartiere Figino',
 'Quartiere Forze Armate',
 'Quartiere Gallaratese',
 'Quartiere Garibaldi Repubblica',
 'Quartiere Ghisolfa',
 'Quartiere Giambellino',
 'Quartiere Giardini Porta Venezia',
 'Quartiere Greco',
 'Quartiere Guastalla',
 'Quartiere Isola',
 'Quartiere Lambrate',
 'Quartiere Lorenteggio',
 'Quartiere Loreto',
 'Quartiere Mecenate',
 'Quartiere Muggiano',
 'Quartiere Navigli',
 'Quartiere Ortomercato',
 'Quartiere Padova',
 'Quartiere Pagano',
 'Quartiere Parco Agricolo Sud',
 'Quartiere Parco Bosco in Città',
 'Quartiere Parco dei Navigli',
 'Quartiere Parco delle Abbazie',
 'Quartiere Parco Nord',
 'Quartiere Parco Sempione',
 'Quartiere Porta Romana',
 'Quartiere Portello',
 'Quartiere Qt 8',
 'Quartiere Quarto Cagnino',
 'Quartiere Quarto Oggiaro',
 'Quartiere Quinto Romano',
 'Quartiere Quintosole',
 'Quartiere Ripamonti',
 'Quartiere Rogoredo',
 'Quartiere Ronchetto delle Rane',
 'Quartiere Ronchetto sul Naviglio',
 'Quartiere Sacco',
 'Quartiere San Cristoforo',
 'Quartiere San Siro',
 'Quartiere Sarpi',
 'Quartiere Scalo Romana',
 'Quartiere Selinunte',
 'Quartiere Stadera',
 'Quartiere Stephenson',
 'Quartiere Tibaldi',
 'Quartiere Ticinese',
 'Quartiere Tortona',
 'Quartiere Tre Torri',
 'Quartiere Trenno',
 'Quartiere Triulzo Superiore',
 'Quartiere Viale Monza',
 'Quartiere Vigentina',
 'Quartiere Villapizzone',
 'Quartiere Washington',
 'Quartiere XXII Marzo'] 

pubblica_utilita = []

#pubblica utilità [2]
subcat_2 = ['farmacie','parrocchie','scuole','uffici postali']
#NB: la categoria 'parrocchie è stata eliminata'!

for q in qrt_list:
    
    url_0 = url_base + subcat_2[0] + '/Milano' + ' ' + q

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(4)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            time.sleep(4)
            cookie_banner_button2.click()
            
    print(f'Downloading data from {url_0}')
    driver.get(url_0)
    time.sleep(4)
    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(3)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_2[0]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Farmacie'): 
            continue
        else:
            diz['category'] = subcat_2[0]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            pubblica_utilita.append(diz)
            


            
for q in qrt_list:
    
    url_2 = url_base + subcat_2[2] + '/Milano' + ' ' + q

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(4)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(4)
            cookie_banner_button2.click()
            
    print(f'Downloading data from {url_2}')
    driver.get(url_2)
    time.sleep(4)
    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(3)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_2[2]}')

    for item in items:
        diz = {}
        diz['category'] = subcat_2[2]
        diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
        diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
        diz['quartiere'] = q
        pubblica_utilita.append(diz)
            
            

for q in qrt_list:
    
    url_3 = url_base + subcat_2[3] + '/Milano' + ' ' + q

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(4)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(4)
            cookie_banner_button2.click()
            
    print(f'Downloading data from {url_3}')
    driver.get(url_3)
    time.sleep(4)
    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(3)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_2[3]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Poste'): 
            continue
        else:
            diz['category'] = subcat_2[3]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            pubblica_utilita.append(diz)
            
            
#salvataggio in csv        
df = pd.DataFrame(pubblica_utilita)
df.to_csv('pubblica_utilità.csv')
# Out:
# Starting operations!
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Adriano
# Trovati 6 elementi per la categoria farmacie
# Closing cookie banner..
# C:\Users\Alberto\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\webelement.py:484: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Affori
# Trovati 10 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Baggio
# Trovati 8 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Bande Nere
# Trovati 18 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Barona
# Trovati 7 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Bicocca
# Trovati 5 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Bovisa
# Trovati 49 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Bovisasca
# Trovati 32 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Bruzzano
# Trovati 35 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Cantalupa
# Trovati 19 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Centrale
# Trovati 28 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Chiaravalle
# Trovati 6 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Città Studi
# Trovati 18 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Comasina
# Trovati 25 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Corsica
# Trovati 10 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Dergano
# Trovati 9 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Duomo
# Trovati 42 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Farini
# Trovati 78 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Figino
# Trovati 25 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Forze Armate
# Trovati 12 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Gallaratese
# Trovati 15 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Garibaldi Repubblica
# Trovati 146 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Ghisolfa
# Trovati 7 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Giambellino
# Trovati 8 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Giardini Porta Venezia
# Trovati 182 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Greco
# Trovati 56 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Guastalla
# Trovati 26 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Isola
# Trovati 13 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Lambrate
# Trovati 11 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Lorenteggio
# Trovati 9 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Loreto
# Trovati 16 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Mecenate
# Trovati 16 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Muggiano
# Trovati 15 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Navigli
# Trovati 11 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Ortomercato
# Trovati 5 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Padova
# Trovati 21 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Pagano
# Trovati 16 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Parco Agricolo Sud
# Trovati 25 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Parco Bosco in Città
# Trovati 23 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Parco dei Navigli
# Trovati 11 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Parco delle Abbazie
# Trovati 200 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Parco Nord
# Trovati 47 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Parco Sempione
# Trovati 147 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Porta Romana
# Trovati 7 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Portello
# Trovati 7 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Qt 8
# Trovati 63 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Quarto Cagnino
# Trovati 7 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Quarto Oggiaro
# Trovati 13 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Quinto Romano
# Trovati 13 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Quintosole
# Trovati 25 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Ripamonti
# Trovati 7 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Rogoredo
# Trovati 5 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Ronchetto delle Rane
# Trovati 14 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Ronchetto sul Naviglio
# Trovati 6 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Sacco
# Trovati 20 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere San Cristoforo
# Trovati 9 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere San Siro
# Trovati 5 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Sarpi
# Trovati 20 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Scalo Romana
# Trovati 5 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Selinunte
# Trovati 13 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Stadera
# Trovati 11 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Stephenson
# Trovati 27 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Tibaldi
# Trovati 5 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Ticinese
# Trovati 19 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Tortona
# Trovati 11 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Tre Torri
# Trovati 109 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Trenno
# Trovati 16 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Triulzo Superiore
# Trovati 11 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Viale Monza
# Trovati 6 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Vigentina
# Trovati 127 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Villapizzone
# Trovati 14 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere Washington
# Trovati 18 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/farmacie/Milano Quartiere XXII Marzo
# Trovati 20 elementi per la categoria farmacie
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Adriano
# Trovati 15 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Affori
# Trovati 23 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Baggio
# Trovati 19 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Bande Nere
# Trovati 46 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Barona
# Trovati 5 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Bicocca
# Trovati 6 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Bovisa
# Trovati 11 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Bovisasca
# Trovati 10 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Bruzzano
# Trovati 9 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Cantalupa
# Trovati 34 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Centrale
# Trovati 49 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Chiaravalle
# Trovati 17 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Città Studi
# Trovati 48 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Comasina
# Trovati 14 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Corsica
# Trovati 12 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Dergano
# Trovati 28 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Duomo
# Trovati 75 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Farini
# Trovati 6 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Figino
# Trovati 14 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Forze Armate
# Trovati 22 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Gallaratese
# Trovati 39 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Garibaldi Repubblica
# Trovati 11 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Ghisolfa
# Trovati 10 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Giambellino
# Trovati 16 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Giardini Porta Venezia
# Trovati 200 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Greco
# Trovati 12 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Guastalla
# Trovati 40 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Isola
# Trovati 20 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Lambrate
# Trovati 22 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Lorenteggio
# Trovati 23 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Loreto
# Trovati 38 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Mecenate
# Trovati 25 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Muggiano
# Trovati 33 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Navigli
# Trovati 26 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Ortomercato
# Trovati 5 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Padova
# Trovati 24 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Pagano
# Trovati 22 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Parco Agricolo Sud
# Trovati 10 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Parco Bosco in Città
# Trovati 44 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Parco dei Navigli
# Trovati 28 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Parco delle Abbazie
# Trovati 200 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Parco Nord
# Trovati 105 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Parco Sempione
# Trovati 200 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Porta Romana
# Trovati 29 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Portello
# Trovati 14 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Qt 8
# Trovati 8 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Quarto Cagnino
# Trovati 7 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Quarto Oggiaro
# Trovati 25 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Quinto Romano
# Trovati 5 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Quintosole
# Trovati 6 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Ripamonti
# Trovati 16 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Rogoredo
# Trovati 5 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Ronchetto delle Rane
# Trovati 20 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Ronchetto sul Naviglio
# Trovati 13 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Sacco
# Trovati 62 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere San Cristoforo
# Trovati 19 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere San Siro
# Trovati 22 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Sarpi
# Trovati 42 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Scalo Romana
# Trovati 15 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Selinunte
# Trovati 19 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Stadera
# Trovati 24 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Stephenson
# Trovati 73 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Tibaldi
# Trovati 178 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Ticinese
# Trovati 42 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Tortona
# Trovati 21 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Tre Torri
# Trovati 200 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Trenno
# Trovati 46 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Triulzo Superiore
# Trovati 31 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Viale Monza
# Trovati 34 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Vigentina
# Trovati 31 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Villapizzone
# Trovati 40 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere Washington
# Trovati 38 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/scuole/Milano Quartiere XXII Marzo
# Trovati 33 elementi per la categoria scuole
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Adriano
# Trovati 11 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Affori
# Trovati 16 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Baggio
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Bande Nere
# Trovati 17 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Barona
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Bicocca
# Trovati 16 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Bovisa
# Trovati 19 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Bovisasca
# Trovati 13 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Bruzzano
# Trovati 7 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Cantalupa
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Centrale
# Trovati 6 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Chiaravalle
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Città Studi
# Trovati 27 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Comasina
# Trovati 12 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Corsica
# Trovati 20 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Dergano
# Trovati 19 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Duomo
# Trovati 10 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Farini
# Trovati 20 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Figino
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Forze Armate
# Trovati 8 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Gallaratese
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Garibaldi Repubblica
# Trovati 30 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Ghisolfa
# Trovati 20 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Giambellino
# Trovati 9 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Giardini Porta Venezia
# Trovati 39 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Greco
# Trovati 21 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Guastalla
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Isola
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Lambrate
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Lorenteggio
# Trovati 10 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Loreto
# Trovati 26 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Mecenate
# Trovati 7 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Muggiano
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Navigli
# Trovati 21 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Ortomercato
# Trovati 14 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Padova
# Trovati 23 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Pagano
# Trovati 23 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Parco Agricolo Sud
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Parco Bosco in Città
# Trovati 7 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Parco dei Navigli
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Parco delle Abbazie
# Trovati 185 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Parco Nord
# Trovati 11 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Parco Sempione
# Trovati 33 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Porta Romana
# Trovati 33 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Portello
# Trovati 17 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Qt 8
# Trovati 7 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Quarto Cagnino
# Trovati 6 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Quarto Oggiaro
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Quinto Romano
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Quintosole
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Ripamonti
# Trovati 11 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Rogoredo
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Ronchetto delle Rane
# Trovati 4 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Ronchetto sul Naviglio
# Trovati 7 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Sacco
# Trovati 10 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere San Cristoforo
# Trovati 14 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere San Siro
# Trovati 8 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Sarpi
# Trovati 27 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Scalo Romana
# Trovati 5 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Selinunte
# Trovati 14 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Stadera
# Trovati 8 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Stephenson
# Trovati 9 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Tibaldi
# Trovati 15 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Ticinese
# Trovati 34 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Tortona
# Trovati 26 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Tre Torri
# Trovati 20 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Trenno
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Triulzo Superiore
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Viale Monza
# Trovati 8 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Vigentina
# Trovati 36 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Villapizzone
# Trovati 9 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere Washington
# Trovati 25 elementi per la categoria uffici postali
# Downloading data from https://www.paginegialle.it/ricerca/uffici postali/Milano Quartiere XXII Marzo
# Trovati 5 elementi per la categoria uffici postali
