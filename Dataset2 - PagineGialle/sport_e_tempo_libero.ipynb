# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.firefox.options import Options as options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
my_firefox_path = r'C:\Users\Alberto\Downloads\geckodriver.exe'
print("Starting operations!")

serv = Service(my_firefox_path)
driver = webdriver.Firefox(service=serv)

url_base = 'https://www.paginegialle.it/ricerca/'

qrt_list = ['Quartiere Adriano',
 'Quartiere Affori',
 'Quartiere Baggio',
 'Quartiere Bande Nere',
 'Quartiere Barona',
 'Quartiere Bicocca',
 'Quartiere Bovisa',
 'Quartiere Bovisasca',
 'Quartiere Bruzzano',
 'Quartiere Cantalupa',
 'Quartiere Centrale',
 'Quartiere Chiaravalle',
 'Quartiere Città Studi',
 'Quartiere Comasina',
 'Quartiere Corsica',
 'Quartiere Dergano',
 'Quartiere Duomo',
 'Quartiere Farini',
 'Quartiere Figino',
 'Quartiere Forze Armate',
 'Quartiere Gallaratese',
 'Quartiere Garibaldi Repubblica',
 'Quartiere Ghisolfa',
 'Quartiere Giambellino',
 'Quartiere Giardini Porta Venezia',
 'Quartiere Greco',
 'Quartiere Guastalla',
 'Quartiere Isola',
 'Quartiere Lambrate',
 'Quartiere Lorenteggio',
 'Quartiere Loreto',
 'Quartiere Mecenate',
 'Quartiere Muggiano',
 'Quartiere Navigli',
 'Quartiere Ortomercato',
 'Quartiere Padova',
 'Quartiere Pagano',
 'Quartiere Parco Agricolo Sud',
 'Quartiere Parco Bosco in Città',
 'Quartiere Parco dei Navigli',
 'Quartiere Parco delle Abbazie',
 'Quartiere Parco Nord',
 'Quartiere Parco Sempione',
 'Quartiere Porta Romana',
 'Quartiere Portello',
 'Quartiere Qt 8',
 'Quartiere Quarto Cagnino',
 'Quartiere Quarto Oggiaro',
 'Quartiere Quinto Romano',
 'Quartiere Quintosole',
 'Quartiere Ripamonti',
 'Quartiere Rogoredo',
 'Quartiere Ronchetto delle Rane',
 'Quartiere Ronchetto sul Naviglio',
 'Quartiere Sacco',
 'Quartiere San Cristoforo',
 'Quartiere San Siro',
 'Quartiere Sarpi',
 'Quartiere Scalo Romana',
 'Quartiere Selinunte',
 'Quartiere Stadera',
 'Quartiere Stephenson',
 'Quartiere Tibaldi',
 'Quartiere Ticinese',
 'Quartiere Tortona',
 'Quartiere Tre Torri',
 'Quartiere Trenno',
 'Quartiere Triulzo Superiore',
 'Quartiere Viale Monza',
 'Quartiere Vigentina',
 'Quartiere Villapizzone',
 'Quartiere Washington',
 'Quartiere XXII Marzo'] 

sport_e_tempo_libero = []

#sport e tempo libero [4]
subcat_4 = ['cinema','librerie','palestre','teatri']

for q in qrt_list:
    
    url_0 = url_base + subcat_4[0] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_0}')
    driver.get(url_0)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            time.sleep(3)
            cookie_banner_button2.click()
               
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_4[0]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Cinema"): 
            continue
        else:
            diz['category'] = subcat_4[0]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            sport_e_tempo_libero.append(diz)

            
for q in qrt_list:
    
    url_1 = url_base + subcat_4[1] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_1}')
    driver.get(url_1)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(3)
            cookie_banner_button2.click()
            
    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_4[1]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Librerie"): 
            continue
        else:
            diz['category'] = subcat_4[1]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            sport_e_tempo_libero.append(diz)
            
            
for q in qrt_list:
    
    url_2 = url_base + subcat_4[2] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_2}')
    driver.get(url_2)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(3)
            cookie_banner_button2.click()
            
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_4[2]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Palestre e fitness'): 
            continue
        else:
            diz['category'] = subcat_4[2]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            sport_e_tempo_libero.append(diz)

            

for q in qrt_list:
    
    url_3 = url_base + subcat_4[3] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_3}')
    driver.get(url_3)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(3)
            cookie_banner_button2.click()
    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_4[3]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Teatri"): 
            continue
        else:
            diz['category'] = subcat_4[3]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            sport_e_tempo_libero.append(diz) 
            

#salvataggio in csv        
df = pd.DataFrame(sport_e_tempo_libero)
df.to_csv('sport_e_tempo_libero.csv')
# Out:
# Starting operations!
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Adriano
# Closing cookie banner..
# Trovati 25 elementi per la categoria cinema
# C:\Users\Alberto\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\webelement.py:484: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Affori
# Trovati 5 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Baggio
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Bande Nere
# Trovati 6 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Barona
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Bicocca
# Trovati 8 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Bovisa
# Trovati 6 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Bovisasca
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Bruzzano
# Trovati 4 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Cantalupa
# Trovati 4 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Centrale
# Trovati 5 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Chiaravalle
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Città Studi
# Trovati 14 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Comasina
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Corsica
# Trovati 8 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Dergano
# Trovati 7 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Duomo
# Trovati 11 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Farini
# Trovati 9 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Figino
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Forze Armate
# Trovati 4 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Gallaratese
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Garibaldi Repubblica
# Trovati 35 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Ghisolfa
# Trovati 8 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Giambellino
# Trovati 4 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Giardini Porta Venezia
# Trovati 34 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Greco
# Trovati 17 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Guastalla
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Isola
# Trovati 20 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Lambrate
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Lorenteggio
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Loreto
# Trovati 6 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Mecenate
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Muggiano
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Navigli
# Trovati 10 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Ortomercato
# Trovati 5 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Padova
# Trovati 5 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Pagano
# Trovati 12 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Parco Agricolo Sud
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Parco Bosco in Città
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Parco dei Navigli
# Trovati 5 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Parco delle Abbazie
# Trovati 76 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Parco Nord
# Trovati 7 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Parco Sempione
# Trovati 31 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Porta Romana
# Trovati 10 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Portello
# Trovati 9 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Qt 8
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Quarto Cagnino
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Quarto Oggiaro
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Quinto Romano
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Quintosole
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Ripamonti
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Rogoredo
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Ronchetto delle Rane
# Trovati 24 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Ronchetto sul Naviglio
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Sacco
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere San Cristoforo
# Trovati 5 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere San Siro
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Sarpi
# Trovati 17 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Scalo Romana
# Trovati 4 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Selinunte
# Trovati 4 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Stadera
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Stephenson
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Tibaldi
# Trovati 4 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Ticinese
# Trovati 19 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Tortona
# Trovati 13 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Tre Torri
# Trovati 12 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Trenno
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Triulzo Superiore
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Viale Monza
# Trovati 4 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Vigentina
# Trovati 20 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Villapizzone
# Trovati 25 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere Washington
# Trovati 16 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/cinema/Milano Quartiere XXII Marzo
# Trovati 21 elementi per la categoria cinema
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Adriano
# Trovati 24 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Affori
# Trovati 8 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Baggio
# Trovati 24 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Bande Nere
# Trovati 12 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Barona
# Trovati 7 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Bicocca
# Trovati 6 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Bovisa
# Trovati 9 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Bovisasca
# Trovati 4 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Bruzzano
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Cantalupa
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Centrale
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Chiaravalle
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Città Studi
# Trovati 8 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Comasina
# Trovati 6 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Corsica
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Dergano
# Trovati 12 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Duomo
# Trovati 27 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Farini
# Trovati 19 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Figino
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Forze Armate
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Gallaratese
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Garibaldi Repubblica
# Trovati 55 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Ghisolfa
# Trovati 21 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Giambellino
# Trovati 9 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Giardini Porta Venezia
# Trovati 90 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Greco
# Trovati 11 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Guastalla
# Trovati 19 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Isola
# Trovati 38 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Lambrate
# Trovati 9 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Lorenteggio
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Loreto
# Trovati 27 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Mecenate
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Muggiano
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Navigli
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Ortomercato
# Trovati 18 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Padova
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Pagano
# Trovati 42 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Parco Agricolo Sud
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Parco Bosco in Città
# Trovati 24 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Parco dei Navigli
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Parco delle Abbazie
# Trovati 195 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Parco Nord
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Parco Sempione
# Trovati 66 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Porta Romana
# Trovati 58 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Portello
# Trovati 21 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Qt 8
# Trovati 10 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Quarto Cagnino
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Quarto Oggiaro
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Quinto Romano
# Trovati 24 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Quintosole
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Ripamonti
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Rogoredo
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Ronchetto delle Rane
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Ronchetto sul Naviglio
# Trovati 7 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Sacco
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere San Cristoforo
# Trovati 21 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere San Siro
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Sarpi
# Trovati 38 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Scalo Romana
# Trovati 12 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Selinunte
# Trovati 13 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Stadera
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Stephenson
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Tibaldi
# Trovati 26 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Ticinese
# Trovati 13 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Tortona
# Trovati 45 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Tre Torri
# Trovati 26 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Trenno
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Triulzo Superiore
# Trovati 25 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Viale Monza
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Vigentina
# Trovati 73 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Villapizzone
# Trovati 7 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere Washington
# Trovati 32 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/librerie/Milano Quartiere XXII Marzo
# Trovati 5 elementi per la categoria librerie
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Adriano
# Trovati 18 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Affori
# Trovati 11 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Baggio
# Trovati 25 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Bande Nere
# Trovati 10 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Barona
# Trovati 17 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Bicocca
# Trovati 5 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Bovisa
# Trovati 30 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Bovisasca
# Trovati 7 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Bruzzano
# Trovati 6 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Cantalupa
# Trovati 8 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Centrale
# Trovati 7 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Chiaravalle
# Trovati 25 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Città Studi
# Trovati 73 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Comasina
# Trovati 5 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Corsica
# Trovati 7 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Dergano
# Trovati 32 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Duomo
# Trovati 34 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Farini
# Trovati 55 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Figino
# Trovati 4 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Forze Armate
# Trovati 25 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Gallaratese
# Trovati 4 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Garibaldi Repubblica
# Trovati 95 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Ghisolfa
# Trovati 10 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Giambellino
# Trovati 17 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Giardini Porta Venezia
# Trovati 110 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Greco
# Trovati 46 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Guastalla
# Trovati 12 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Isola
# Trovati 9 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Lambrate
# Trovati 20 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Lorenteggio
# Trovati 15 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Loreto
# Trovati 14 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Mecenate
# Trovati 10 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Muggiano
# Trovati 25 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Navigli
# Trovati 10 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Ortomercato
# Trovati 38 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Padova
# Trovati 7 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Pagano
# Trovati 74 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Parco Agricolo Sud
# Trovati 25 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Parco Bosco in Città
# Trovati 10 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Parco dei Navigli
# Trovati 7 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Parco delle Abbazie
# Trovati 200 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Parco Nord
# Trovati 12 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Parco Sempione
# Trovati 102 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Porta Romana
# Trovati 10 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Portello
# Trovati 50 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Qt 8
# Trovati 29 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Quarto Cagnino
# Trovati 13 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Quarto Oggiaro
# Trovati 6 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Quinto Romano
# Trovati 6 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Quintosole
# Trovati 25 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Ripamonti
# Trovati 20 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Rogoredo
# Trovati 5 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Ronchetto delle Rane
# Trovati 5 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Ronchetto sul Naviglio
# Trovati 8 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Sacco
# Trovati 4 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere San Cristoforo
# Trovati 38 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere San Siro
# Trovati 5 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Sarpi
# Trovati 14 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Scalo Romana
# Trovati 5 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Selinunte
# Trovati 33 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Stadera
# Trovati 21 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Stephenson
# Trovati 5 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Tibaldi
# Trovati 54 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Ticinese
# Trovati 5 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Tortona
# Trovati 72 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Tre Torri
# Trovati 57 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Trenno
# Trovati 6 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Triulzo Superiore
# Trovati 4 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Viale Monza
# Trovati 9 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Vigentina
# Trovati 10 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Villapizzone
# Trovati 11 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere Washington
# Trovati 12 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/palestre/Milano Quartiere XXII Marzo
# Trovati 8 elementi per la categoria palestre
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Adriano
# Trovati 25 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Affori
# Trovati 25 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Baggio
# Trovati 25 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Bande Nere
# Trovati 6 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Barona
# Trovati 11 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Bicocca
# Trovati 9 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Bovisa
# Trovati 9 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Bovisasca
# Trovati 25 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Bruzzano
# Trovati 4 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Cantalupa
# Trovati 5 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Centrale
# Trovati 21 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Chiaravalle
# Trovati 25 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Città Studi
# Trovati 11 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Comasina
# Trovati 25 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Corsica
# Trovati 7 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Dergano
# Trovati 15 elementi per la categoria teatri
# Downloading data from https://www.paginegialle.it/ricerca/teatri/Milano Quartiere Duomo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-d2cf245977a8> in <module>
#     233     mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
#     234     while len(mostra_altri) > 0 :
# --> 235         mostra_altri[0].click()
#     236         time.sleep(2)
#     237         mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
#
# ~\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      79     def click(self) -> None:
#      80         """Clicks the element."""
# ---> 81         self._execute(Command.CLICK_ELEMENT)
#      82
#      83     def submit(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     420
#     421         params = self._wrap_value(params)
# --> 422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
#     424             self.error_handler.check_response(response)
#
# ~\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     419         data = utils.dump_json(params)
#     420         url = f"{self._url}{path}"
# --> 421         return self._request(command_info[0], url, body=data)
#     422
#     423     def _request(self, method, url, body=None):
#
# ~\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     441
#     442         if self.keep_alive:
# --> 443             resp = self._conn.request(method, url, body=body, headers=headers)
#     444             statuscode = resp.status
#     445         else:
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77         else:
#      78             return self.request_encode_body(
# ---> 79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#      81
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Roaming\Python\Python37\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\Anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~\Anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~\Anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
