# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.firefox.options import Options as options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
my_firefox_path = r'C:\Users\Alberto\Downloads\geckodriver.exe'
print("Starting operations!")

serv = Service(my_firefox_path)
driver = webdriver.Firefox(service=serv)

url_base = 'https://www.paginegialle.it/ricerca/'

qrt_list = ['Quartiere Adriano',
 'Quartiere Affori',
 'Quartiere Baggio',
 'Quartiere Bande Nere',
 'Quartiere Barona',
 'Quartiere Bicocca',
 'Quartiere Bovisa',
 'Quartiere Bovisasca',
 'Quartiere Bruzzano',
 'Quartiere Cantalupa',
 'Quartiere Centrale',
 'Quartiere Chiaravalle',
 'Quartiere Città Studi',
 'Quartiere Comasina',
 'Quartiere Corsica',
 'Quartiere Dergano',
 'Quartiere Duomo',
 'Quartiere Farini',
 'Quartiere Figino',
 'Quartiere Forze Armate',
 'Quartiere Gallaratese',
 'Quartiere Garibaldi Repubblica',
 'Quartiere Ghisolfa',
 'Quartiere Giambellino',
 'Quartiere Giardini Porta Venezia',
 'Quartiere Greco',
 'Quartiere Guastalla',
 'Quartiere Isola',
 'Quartiere Lambrate',
 'Quartiere Lorenteggio',
 'Quartiere Loreto',
 'Quartiere Mecenate',
 'Quartiere Muggiano',
 'Quartiere Navigli',
 'Quartiere Ortomercato',
 'Quartiere Padova',
 'Quartiere Pagano',
 'Quartiere Parco Agricolo Sud',
 'Quartiere Parco Bosco in Città',
 'Quartiere Parco dei Navigli',
 'Quartiere Parco delle Abbazie',
 'Quartiere Parco Nord',
 'Quartiere Parco Sempione',
 'Quartiere Porta Romana',
 'Quartiere Portello',
 'Quartiere Qt 8',
 'Quartiere Quarto Cagnino',
 'Quartiere Quarto Oggiaro',
 'Quartiere Quinto Romano',
 'Quartiere Quintosole',
 'Quartiere Ripamonti',
 'Quartiere Rogoredo',
 'Quartiere Ronchetto delle Rane',
 'Quartiere Ronchetto sul Naviglio',
 'Quartiere Sacco',
 'Quartiere San Cristoforo',
 'Quartiere San Siro',
 'Quartiere Sarpi',
 'Quartiere Scalo Romana',
 'Quartiere Selinunte',
 'Quartiere Stadera',
 'Quartiere Stephenson',
 'Quartiere Tibaldi',
 'Quartiere Ticinese',
 'Quartiere Tortona',
 'Quartiere Tre Torri',
 'Quartiere Trenno',
 'Quartiere Triulzo Superiore',
 'Quartiere Viale Monza',
 'Quartiere Vigentina',
 'Quartiere Villapizzone',
 'Quartiere Washington',
 'Quartiere XXII Marzo'] 

mangiare = []

#mangiare [1]
subcat_1 = ['bar','ristoranti','gelaterie']
        
    
for q in qrt_list:
    
    url_0 = url_base + subcat_1[0] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_0}')
    driver.get(url_0)
    time.sleep(8)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(8)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            time.sleep(8)
            cookie_banner_button2.click()

    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(8)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_1[0]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Bar e caffe''): 
            continue
        else:
            diz['category'] = subcat_1[0]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            mangiare.append(diz)
            
            
for q in qrt_list:
    
    url_1 = url_base + subcat_1[1] + '/Milano' + ' ' + q

    print(f'Downloading data from {url_1}')
    driver.get(url_1)
    time.sleep(8)
    
    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(8)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            time.sleep(8)
            cookie_banner_button2.click()

    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(8)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_1[1]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Ristoranti'): 
            continue
        else:
            diz['category'] = subcat_1[1]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            mangiare.append(diz)
            
            
            
for q in qrt_list:
    
    url_2 = url_base + subcat_1[2] + '/Milano' + ' ' + q

    print(f'Downloading data from {url_2}')
    driver.get(url_2)
    time.sleep(8)
    
    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(8)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            time.sleep(8)
            cookie_banner_button2.click()

    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(8)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_1[2]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Gelaterie'): 
            continue
        else:
            diz['category'] = subcat_1[2]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            mangiare.append(diz)

            
#salvataggio in csv        
df = pd.DataFrame(mangiare)
df.to_csv('mangiare.csv')
# Out:
# Starting operations!
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Adriano
# Trovati 11 elementi per la categoria bar
# Closing cookie banner..
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Affori
# Trovati 19 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Baggio
# Trovati 18 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Bande Nere
# Trovati 48 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Barona
# Trovati 9 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Bicocca
# Trovati 21 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Bovisa
# Trovati 28 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Bovisasca
# Trovati 67 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Bruzzano
# Trovati 5 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Cantalupa
# Trovati 32 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Centrale
# Trovati 169 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Chiaravalle
# Trovati 31 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Città Studi
# Trovati 65 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Comasina
# Trovati 6 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Corsica
# Trovati 30 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Dergano
# Trovati 16 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Duomo
# Trovati 200 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Farini
# Trovati 13 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Figino
# Trovati 28 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Forze Armate
# Trovati 13 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Gallaratese
# Trovati 13 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Garibaldi Repubblica
# Trovati 45 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Ghisolfa
# Trovati 24 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Giambellino
# Trovati 27 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Giardini Porta Venezia
# Trovati 200 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Greco
# Trovati 14 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Guastalla
# Trovati 104 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Isola
# Trovati 80 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Lambrate
# Trovati 25 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Lorenteggio
# Trovati 14 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Loreto
# Trovati 55 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Mecenate
# Trovati 25 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Muggiano
# Trovati 28 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Navigli
# Trovati 86 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Ortomercato
# Trovati 8 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Padova
# Trovati 37 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Pagano
# Trovati 43 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Parco Agricolo Sud
# Trovati 13 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Parco Bosco in Città
# Trovati 7 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Parco dei Navigli
# Trovati 27 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Parco delle Abbazie
# Trovati 200 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Parco Nord
# Trovati 66 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Parco Sempione
# Trovati 5 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Porta Romana
# Trovati 61 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Portello
# Trovati 16 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Qt 8
# Trovati 150 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Quarto Cagnino
# Trovati 45 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Quarto Oggiaro
# Trovati 14 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Quinto Romano
# Trovati 24 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Quintosole
# Trovati 4 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Ripamonti
# Trovati 11 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Rogoredo
# Trovati 11 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Ronchetto delle Rane
# Trovati 27 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Ronchetto sul Naviglio
# Trovati 11 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Sacco
# Trovati 51 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere San Cristoforo
# Trovati 13 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere San Siro
# Trovati 14 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Sarpi
# Trovati 108 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Scalo Romana
# Trovati 21 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Selinunte
# Trovati 12 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Stadera
# Trovati 15 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Stephenson
# Trovati 5 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Tibaldi
# Trovati 15 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Ticinese
# Trovati 72 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Tortona
# Trovati 48 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Tre Torri
# Trovati 200 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Trenno
# Trovati 30 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Triulzo Superiore
# Trovati 49 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Viale Monza
# Trovati 27 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Vigentina
# Trovati 36 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Villapizzone
# Trovati 43 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere Washington
# Trovati 53 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/bar/Milano Quartiere XXII Marzo
# Trovati 77 elementi per la categoria bar
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Adriano
# Trovati 21 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Affori
# Trovati 47 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Baggio
# Trovati 27 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Bande Nere
# Trovati 96 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Barona
# Trovati 13 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Bicocca
# Trovati 102 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Bovisa
# Trovati 67 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Bovisasca
# Trovati 10 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Bruzzano
# Trovati 12 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Cantalupa
# Trovati 75 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Centrale
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Chiaravalle
# Trovati 59 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Città Studi
# Trovati 175 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Comasina
# Trovati 5 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Corsica
# Trovati 60 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Dergano
# Trovati 67 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Duomo
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Farini
# Trovati 33 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Figino
# Trovati 39 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Forze Armate
# Trovati 27 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Gallaratese
# Trovati 27 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Garibaldi Repubblica
# Trovati 152 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Ghisolfa
# Trovati 80 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Giambellino
# Trovati 77 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Giardini Porta Venezia
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Greco
# Trovati 26 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Guastalla
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Isola
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Lambrate
# Trovati 58 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Lorenteggio
# Trovati 26 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Loreto
# Trovati 184 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Mecenate
# Trovati 30 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Muggiano
# Trovati 41 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Navigli
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Ortomercato
# Trovati 10 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Padova
# Trovati 78 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Pagano
# Trovati 99 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Parco Agricolo Sud
# Trovati 22 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Parco Bosco in Città
# Trovati 23 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Parco dei Navigli
# Trovati 58 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Parco delle Abbazie
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Parco Nord
# Trovati 150 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Parco Sempione
# Trovati 16 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Porta Romana
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Portello
# Trovati 23 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Qt 8
# Trovati 5 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Quarto Cagnino
# Trovati 10 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Quarto Oggiaro
# Trovati 15 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Quinto Romano
# Trovati 6 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Quintosole
# Trovati 9 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Ripamonti
# Trovati 31 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Rogoredo
# Trovati 13 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Ronchetto delle Rane
# Trovati 53 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Ronchetto sul Naviglio
# Trovati 28 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Sacco
# Trovati 76 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere San Cristoforo
# Trovati 48 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere San Siro
# Trovati 33 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Sarpi
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Scalo Romana
# Trovati 41 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Selinunte
# Trovati 49 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Stadera
# Trovati 38 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Stephenson
# Trovati 6 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Tibaldi
# Trovati 34 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Ticinese
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Tortona
# Trovati 165 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Tre Torri
# Trovati 22 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Trenno
# Trovati 5 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Triulzo Superiore
# Trovati 5 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Viale Monza
# Trovati 80 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Vigentina
# Trovati 120 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Villapizzone
# Trovati 119 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere Washington
# Trovati 107 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/ristoranti/Milano Quartiere XXII Marzo
# Trovati 200 elementi per la categoria ristoranti
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Adriano
# Trovati 6 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Affori
# Trovati 9 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Baggio
# Trovati 4 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Bande Nere
# Trovati 31 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Barona
# Trovati 7 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Bicocca
# Trovati 12 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Bovisa
# Trovati 6 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Bovisasca
# Trovati 4 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Bruzzano
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Cantalupa
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Centrale
# Trovati 6 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Chiaravalle
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Città Studi
# Trovati 13 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Comasina
# Trovati 5 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Corsica
# Trovati 36 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Dergano
# Trovati 19 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Duomo
# Trovati 24 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Farini
# Trovati 37 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Figino
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Forze Armate
# Trovati 8 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Gallaratese
# Trovati 4 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Garibaldi Repubblica
# Trovati 56 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Ghisolfa
# Trovati 29 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Giambellino
# Trovati 14 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Giardini Porta Venezia
# Trovati 79 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Greco
# Trovati 23 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Guastalla
# Trovati 11 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Isola
# Trovati 7 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Lambrate
# Trovati 15 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Lorenteggio
# Trovati 8 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Loreto
# Trovati 13 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Mecenate
# Trovati 5 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Muggiano
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Navigli
# Trovati 9 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Ortomercato
# Trovati 29 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Padova
# Trovati 6 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Pagano
# Trovati 7 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Parco Agricolo Sud
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Parco Bosco in Città
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Parco dei Navigli
# Trovati 4 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Parco delle Abbazie
# Trovati 200 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Parco Nord
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Parco Sempione
# Trovati 82 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Porta Romana
# Trovati 9 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Portello
# Trovati 35 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Qt 8
# Trovati 8 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Quarto Cagnino
# Trovati 4 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Quarto Oggiaro
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Quinto Romano
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Quintosole
# Trovati 25 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Ripamonti
# Trovati 10 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Rogoredo
# Trovati 10 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Ronchetto delle Rane
# Trovati 4 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Ronchetto sul Naviglio
# Trovati 10 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Sacco
# Trovati 5 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere San Cristoforo
# Trovati 33 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere San Siro
# Trovati 9 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Sarpi
# Trovati 12 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Scalo Romana
# Trovati 26 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Selinunte
# Trovati 23 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Stadera
# Trovati 10 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Stephenson
# Trovati 7 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Tibaldi
# Trovati 36 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Ticinese
# Trovati 15 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Tortona
# Trovati 5 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Tre Torri
# Trovati 40 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Trenno
# Trovati 4 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Triulzo Superiore
# Trovati 8 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Viale Monza
# Trovati 14 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Vigentina
# Trovati 86 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Villapizzone
# Trovati 14 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere Washington
# Trovati 48 elementi per la categoria gelaterie
# Downloading data from https://www.paginegialle.it/ricerca/gelaterie/Milano Quartiere XXII Marzo
# Trovati 10 elementi per la categoria gelaterie
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-823e7b99c17e> in <module>
#     212
#     213 #salvataggio in csv
# --> 214 df = pd.DataFrame(fare_la_spesa)
#     215 df.to_csv('mangiare.csv')
#
# NameError: name 'fare_la_spesa' is not defined
