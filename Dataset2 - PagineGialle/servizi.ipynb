# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.firefox.options import Options as options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
import pandas as pd
import time

# %%
my_firefox_path = r'C:\Users\Alberto\Downloads\geckodriver.exe'
print("Starting operations!")

serv = Service(my_firefox_path)
driver = webdriver.Firefox(service=serv)

url_base = 'https://www.paginegialle.it/ricerca/'

qrt_list = ['Quartiere Adriano',
 'Quartiere Affori',
 'Quartiere Baggio',
 'Quartiere Bande Nere',
 'Quartiere Barona',
 'Quartiere Bicocca',
 'Quartiere Bovisa',
 'Quartiere Bovisasca',
 'Quartiere Bruzzano',
 'Quartiere Cantalupa',
 'Quartiere Centrale',
 'Quartiere Chiaravalle',
 'Quartiere Città Studi',
 'Quartiere Comasina',
 'Quartiere Corsica',
 'Quartiere Dergano',
 'Quartiere Duomo',
 'Quartiere Farini',
 'Quartiere Figino',
 'Quartiere Forze Armate',
 'Quartiere Gallaratese',
 'Quartiere Garibaldi Repubblica',
 'Quartiere Ghisolfa',
 'Quartiere Giambellino',
 'Quartiere Giardini Porta Venezia',
 'Quartiere Greco',
 'Quartiere Guastalla',
 'Quartiere Isola',
 'Quartiere Lambrate',
 'Quartiere Lorenteggio',
 'Quartiere Loreto',
 'Quartiere Mecenate',
 'Quartiere Muggiano',
 'Quartiere Navigli',
 'Quartiere Ortomercato',
 'Quartiere Padova',
 'Quartiere Pagano',
 'Quartiere Parco Agricolo Sud',
 'Quartiere Parco Bosco in Città',
 'Quartiere Parco dei Navigli',
 'Quartiere Parco delle Abbazie',
 'Quartiere Parco Nord',
 'Quartiere Parco Sempione',
 'Quartiere Porta Romana',
 'Quartiere Portello',
 'Quartiere Qt 8',
 'Quartiere Quarto Cagnino',
 'Quartiere Quarto Oggiaro',
 'Quartiere Quinto Romano',
 'Quartiere Quintosole',
 'Quartiere Ripamonti',
 'Quartiere Rogoredo',
 'Quartiere Ronchetto delle Rane',
 'Quartiere Ronchetto sul Naviglio',
 'Quartiere Sacco',
 'Quartiere San Cristoforo',
 'Quartiere San Siro',
 'Quartiere Sarpi',
 'Quartiere Scalo Romana',
 'Quartiere Selinunte',
 'Quartiere Stadera',
 'Quartiere Stephenson',
 'Quartiere Tibaldi',
 'Quartiere Ticinese',
 'Quartiere Tortona',
 'Quartiere Tre Torri',
 'Quartiere Trenno',
 'Quartiere Triulzo Superiore',
 'Quartiere Viale Monza',
 'Quartiere Vigentina',
 'Quartiere Villapizzone',
 'Quartiere Washington',
 'Quartiere XXII Marzo'] 

servizi = []

#servizi [3]
subcat_3 = ['asili nido','banche','lavanderie','ricevitorie','tabaccherie']

for q in qrt_list:
    
    url_0 = url_base + subcat_3[0] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_0}')
    driver.get(url_0)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            time.sleep(3)
            cookie_banner_button2.click()
               
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_3[0]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Nidi d'infanzia"): 
            continue
        else:
            diz['category'] = subcat_3[0]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            servizi.append(diz)

            
            
for q in qrt_list:
    
    url_1 = url_base + subcat_3[1] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_1}')
    driver.get(url_1)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(3)
            cookie_banner_button2.click()
            
    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_3[1]}')

    for item in items:
        diz = {}
        diz['category'] = subcat_3[1]
        diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
        diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
        diz['quartiere'] = q
        servizi.append(diz)
            
            
            
for q in qrt_list:
    
    url_2 = url_base + subcat_3[2] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_2}')
    driver.get(url_2)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(3)
            cookie_banner_button2.click()
            
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_3[2]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Lavanderie'): 
            continue
        else:
            diz['category'] = subcat_3[2]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            servizi.append(diz)

            
            
for q in qrt_list:
    
    url_3 = url_base + subcat_3[3] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_3}')
    driver.get(url_3)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(3)
            cookie_banner_button2.click()
    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_3[3]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Lotto, ricevitorie concorsi e giocate"): 
            continue
        else:
            diz['category'] = subcat_3[3]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            servizi.append(diz)
            
            
            
for q in qrt_list:
    
    url_4 = url_base + subcat_3[4] + '/Milano' + ' ' + q
    
    print(f'Downloading data from {url_4}')
    driver.get(url_4)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        #time.sleep(3)
        cookie_banner_button.click()
        if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
            cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
            #time.sleep(3)
            cookie_banner_button2.click()
    
    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_3[4]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Tabaccherie'): 
            continue
        else:
            diz['category'] = subcat_3[4]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            servizi.append(diz)
                        
            
#salvataggio in csv        
df = pd.DataFrame(servizi)
df.to_csv('servizi.csv')
# Out:
# Starting operations!
# ...
# Closing cookie banner..
# Trovati 7 elementi per la categoria asili nido
# ...
# C:\Users\Alberto\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\webelement.py:484: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# Trovati 9 elementi per la categoria asili nido
# ...
# Trovati 6 elementi per la categoria asili nido
# ...
# Trovati 13 elementi per la categoria asili nido
# ...
# Trovati 14 elementi per la categoria asili nido
# ...
# Trovati 32 elementi per la categoria asili nido
# ...
# Trovati 36 elementi per la categoria asili nido
# ...
# Trovati 15 elementi per la categoria asili nido
# ...
# Trovati 16 elementi per la categoria asili nido
# ...
# Trovati 10 elementi per la categoria asili nido
# ...
# Trovati 11 elementi per la categoria asili nido
# ...
# Trovati 7 elementi per la categoria asili nido
# ...
# Trovati 9 elementi per la categoria asili nido
# ...
