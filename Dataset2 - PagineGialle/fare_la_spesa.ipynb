# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.firefox.options import Options as options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
import pandas as pd
import time

my_firefox_path = r'C:\Users\Alberto\Downloads\geckodriver.exe'
print("Starting operations!")

serv = Service(my_firefox_path)
driver = webdriver.Firefox(service=serv)

url_base = 'https://www.paginegialle.it/ricerca/'

fare_la_spesa = []

''' #recupera lista dei quartieri
#lista dei quartieri
qrt = driver.find_elements(By.CLASS_NAME, "box-corr__itm")
qrt_list=[]
for i in range(0,73):
    qrt_list.append(qrt[i].text)

button = driver.find_elements_by_xpath("/html/body/main/div/div[2]/div[1]/div[2]/div[3]/div[3]/a")[0]
button.click()
'''
    
qrt_list = ['Quartiere Adriano',
 'Quartiere Affori',
 'Quartiere Baggio',
 'Quartiere Bande Nere',
 'Quartiere Barona',
 'Quartiere Bicocca',
 'Quartiere Bovisa',
 'Quartiere Bovisasca',
 'Quartiere Bruzzano',
 'Quartiere Cantalupa',
 'Quartiere Centrale',
 'Quartiere Chiaravalle',
 'Quartiere Città Studi',
 'Quartiere Comasina',
 'Quartiere Corsica',
 'Quartiere Dergano',
 'Quartiere Duomo',
 'Quartiere Farini',
 'Quartiere Figino',
 'Quartiere Forze Armate',
 'Quartiere Gallaratese',
 'Quartiere Garibaldi Repubblica',
 'Quartiere Ghisolfa',
 'Quartiere Giambellino',
 'Quartiere Giardini Porta Venezia',
 'Quartiere Greco',
 'Quartiere Guastalla',
 'Quartiere Isola',
 'Quartiere Lambrate',
 'Quartiere Lorenteggio',
 'Quartiere Loreto',
 'Quartiere Mecenate',
 'Quartiere Muggiano',
 'Quartiere Navigli',
 'Quartiere Ortomercato',
 'Quartiere Padova',
 'Quartiere Pagano',
 'Quartiere Parco Agricolo Sud',
 'Quartiere Parco Bosco in Città',
 'Quartiere Parco dei Navigli',
 'Quartiere Parco delle Abbazie',
 'Quartiere Parco Nord',
 'Quartiere Parco Sempione',
 'Quartiere Porta Romana',
 'Quartiere Portello',
 'Quartiere Qt 8',
 'Quartiere Quarto Cagnino',
 'Quartiere Quarto Oggiaro',
 'Quartiere Quinto Romano',
 'Quartiere Quintosole',
 'Quartiere Ripamonti',
 'Quartiere Rogoredo',
 'Quartiere Ronchetto delle Rane',
 'Quartiere Ronchetto sul Naviglio',
 'Quartiere Sacco',
 'Quartiere San Cristoforo',
 'Quartiere San Siro',
 'Quartiere Sarpi',
 'Quartiere Scalo Romana',
 'Quartiere Selinunte',
 'Quartiere Stadera',
 'Quartiere Stephenson',
 'Quartiere Tibaldi',
 'Quartiere Ticinese',
 'Quartiere Tortona',
 'Quartiere Tre Torri',
 'Quartiere Trenno',
 'Quartiere Triulzo Superiore',
 'Quartiere Viale Monza',
 'Quartiere Vigentina',
 'Quartiere Villapizzone',
 'Quartiere Washington',
 'Quartiere XXII Marzo']    

#fare la spesa
subcat_0 = ['alimentari','discount','frutta e verdura','macellerie','panetterie','pescherie'] 

for q in qrt_list:
    
    url_0 = url_base + subcat_0[0] + '/Milano' + ' ' + q
    
    driver.get(url_0)
    time.sleep(5)
    
    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btn ubl")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btn")[0]
        time.sleep(3)
        cookie_banner_button.click()
    if len (driver.find_elements(By.ID, "iubFooterBtn")) != 0:
        cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
        time.sleep(3)
        cookie_banner_button2.click() 

    print(f'Downloading data from {url_0}')

    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_0[0]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Alimentari"): 
            continue
        else:  
            diz['category'] = subcat_0[0]
            diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
            diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
            diz['quartiere'] = q
            fare_la_spesa.append(diz)

        
for q in qrt_list:        

    url_1 = url_base + subcat_0[1] + '/Milano' + ' ' + q

    print(f'Downloading data from {url_1}')
    driver.get(url_1)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(2)
        cookie_banner_button.click()
        cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
        time.sleep(2)
        cookie_banner_button2.click()  

    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_0[1]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Supermercati e discount"): 
            continue
        if ((item.find_element_by_css_selector("h2[itemprop='name']").text) == 'Coin'):
            continue
        if ((item.find_element_by_css_selector("h2[itemprop='name']").text) == 'Coin Excelsior'):
            continue
        if ((item.find_element_by_css_selector("h2[itemprop='name']").text) == 'Ovs'):
            continue
        diz['category'] = subcat_0[1]
        diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
        diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
        diz['quartiere'] = q
        fare_la_spesa.append(diz)


        
for q in qrt_list:
        
    url_2 = url_base + subcat_0[2] + '/Milano' + ' ' + q

    print(f'Downloading data from {url_2}')
    driver.get(url_2)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(2)
        cookie_banner_button.click()
        cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
        time.sleep(2)
        cookie_banner_button2.click()  

    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_0[2]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Frutta e verdura"): 
            continue
        diz['category'] = subcat_0[2]
        diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
        diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
        diz['quartiere'] = q
        fare_la_spesa.append(diz)


for q in qrt_list:        
    
    url_3 = url_base + subcat_0[3] + '/Milano' + ' ' + q

    print(f'Downloading data from {url_3}')
    driver.get(url_3)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(2)
        cookie_banner_button.click()
        cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
        time.sleep(2)
        cookie_banner_button2.click()  

    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_0[3]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != "Macellerie"): 
            continue
        diz['category'] = subcat_0[3]
        diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
        diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
        diz['quartiere'] = q
        fare_la_spesa.append(diz)  

        
for q in qrt_list:        
    
    url_4 = url_base + subcat_0[4] + '/Milano' + ' ' + q

    print(f'Downloading data from {url_4}')
    driver.get(url_4)
    time.sleep(3)

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(2)
        cookie_banner_button.click()
        cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
        time.sleep(2)
        cookie_banner_button2.click()  

    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_0[4]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Panetterie'):
            continue
        diz['category'] = subcat_0[4]
        diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
        diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
        diz['quartiere'] = q
        fare_la_spesa.append(diz)

    
for q in qrt_list:    
    
    url_5 = url_base + subcat_0[5] + '/Milano' + ' ' + q

    print(f'Downloading data from {url_5}')
    driver.get(url_5)
    time.sleep(3) 

    #Check cookie banner
    if len(driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")) != 0:
        print('Closing cookie banner..')
        cookie_banner_button = driver.find_elements(By.CLASS_NAME, "ubl-cst__btns")[0]
        time.sleep(2)
        cookie_banner_button.click()
        cookie_banner_button2 =driver.find_elements(By.ID, "iubFooterBtn")[0]
        time.sleep(2)
        cookie_banner_button2.click()  

    #show all results
    mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')
    while len(mostra_altri) > 0 :
        mostra_altri[0].click()
        time.sleep(2)
        mostra_altri = driver.find_elements(By.LINK_TEXT, 'MOSTRA ALTRI RISULTATI')

    items = driver.find_elements(By.CLASS_NAME, 'search-itm__content')
    print(f'Trovati {len(items)} elementi per la categoria {subcat_0[5]}')

    for item in items:
        diz = {}
        if ((item.find_element_by_css_selector("div[class='search-itm__category']").text) != 'Pescherie'):
            continue
        diz['category'] = subcat_0[5]
        diz['name'] = item.find_element_by_css_selector("h2[itemprop='name']").text
        diz['address'] = item.find_element_by_css_selector("div[class='search-itm__adr']").text
        diz['quartiere'] = q
        fare_la_spesa.append(diz)     
        

#salvataggio in csv        
df = pd.DataFrame(fare_la_spesa)
df.to_csv('fare_la_spesa.csv')
# Out:
# Starting operations!
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Adriano
# Trovati 17 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Affori
# Trovati 17 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Baggio
# Trovati 11 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Bande Nere
# Trovati 12 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Barona
# Trovati 8 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Bicocca
# Trovati 18 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Bovisa
# Trovati 20 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Bovisasca
# Trovati 11 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Bruzzano
# Trovati 14 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Cantalupa
# Trovati 25 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Centrale
# Trovati 21 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Chiaravalle
# Trovati 7 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Città Studi
# Trovati 11 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Comasina
# Trovati 14 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Corsica
# Trovati 8 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Dergano
# Trovati 5 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Duomo
# Trovati 47 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Farini
# Trovati 61 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Figino
# Trovati 11 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Forze Armate
# Trovati 19 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Gallaratese
# Trovati 7 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Garibaldi Repubblica
# Trovati 132 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Ghisolfa
# Trovati 5 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Giambellino
# Trovati 9 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Giardini Porta Venezia
# Trovati 181 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Greco
# Trovati 46 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Guastalla
# Trovati 7 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Isola
# Trovati 13 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Lambrate
# Trovati 21 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Lorenteggio
# Trovati 22 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Loreto
# Trovati 17 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Mecenate
# Trovati 63 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Muggiano
# Trovati 7 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Navigli
# Trovati 7 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Ortomercato
# Trovati 50 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Padova
# Trovati 14 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Pagano
# Trovati 10 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Parco Agricolo Sud
# Trovati 5 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Parco Bosco in Città
# Trovati 8 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Parco dei Navigli
# Trovati 25 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Parco delle Abbazie
# Trovati 200 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Parco Nord
# Trovati 7 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Parco Sempione
# Trovati 142 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Porta Romana
# Trovati 16 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Portello
# Trovati 41 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Qt 8
# Trovati 11 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Quarto Cagnino
# Trovati 7 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Quarto Oggiaro
# Trovati 11 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Quinto Romano
# Trovati 8 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Quintosole
# Trovati 25 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Ripamonti
# Trovati 16 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Rogoredo
# Trovati 13 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Ronchetto delle Rane
# Trovati 5 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Ronchetto sul Naviglio
# Trovati 16 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Sacco
# Trovati 12 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere San Cristoforo
# Trovati 36 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere San Siro
# Trovati 14 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Sarpi
# Trovati 20 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Scalo Romana
# Trovati 40 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Selinunte
# Trovati 37 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Stadera
# Trovati 12 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Stephenson
# Trovati 14 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Tibaldi
# Trovati 41 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Ticinese
# Trovati 13 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Tortona
# Trovati 5 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Tre Torri
# Trovati 6 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Trenno
# Trovati 14 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Triulzo Superiore
# Trovati 13 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Viale Monza
# Trovati 9 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Vigentina
# Trovati 8 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Villapizzone
# Trovati 11 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere Washington
# Trovati 9 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/alimentari/Milano Quartiere XXII Marzo
# Trovati 17 elementi per la categoria alimentari
# Downloading data from https://www.paginegialle.it/ricerca/discount/Milano Quartiere Adriano
# Trovati 3 elementi per la categoria discount
# Downloading data from https://www.paginegialle.it/ricerca/discount/Milano Quartiere Affori
# Trovati 6 elementi per la categoria discount
# Downloading data from https://www.paginegialle.it/ricerca/discount/Milano Quartiere Baggio
# Trovati 9 elementi per la categoria discount
# Downloading data from https://www.paginegialle.it/ricerca/discount/Milano Quartiere Bande Nere
# Trovati 15 elementi per la categoria discount
# Downloading data from https://www.paginegialle.it/ricerca/discount/Milano Quartiere Barona
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4140\2213058885.py in <module>
#     153
#     154     print(f'Downloading data from {url_1}')
# --> 155     driver.get(url_1)
#     156     time.sleep(3)
#     157
#
# ~\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# ~\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\AppData\Roaming\Python\Python37\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# TimeoutException: Message: TimedPromise timed out after 300000 ms
# Stacktrace:
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.jsm:183:5
# TimeoutError@chrome://remote/content/shared/webdriver/Errors.jsm:472:5
# bail@chrome://remote/content/marionette/sync.js:227:19
